# %%
# PPO
# !python train_ppo.py \
  --env-id MetaDrive-Tut-1Env-v0 \
  --log-dir MetaDrive-Tut-1Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --restore \
  > ppo_metadrive_1env_train.log 2>&1 
  
# !python train_ppo.py \
  --env-id MetaDrive-Tut-5Env-v0 \
  --log-dir MetaDrive-Tut-5Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --restore \
  > ppo_metadrive_5env_train.log 2>&1 

# !python train_ppo.py \
  --env-id MetaDrive-Tut-10Env-v0 \
  --log-dir MetaDrive-Tut-10Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --restore \
  > ppo_metadrive_10env_train.log 2>&1 

# !python train_ppo.py \
  --env-id MetaDrive-Tut-20Env-v0 \
  --log-dir MetaDrive-Tut-20Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --restore \
  > ppo_metadrive_20env_train.log 2>&1 

# !python train_ppo.py \
  --env-id MetaDrive-Tut-100Env-v0 \
  --log-dir MetaDrive-Tut-100Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --restore \
  > ppo_metadrive_100env_train.log 2>&1

# %%
# !python train_ppo.py \
  --env-id MetaDrive-Tut-50Env-v0 \
  --log-dir MetaDrive-Tut-50Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --restore \
  > ppo_metadrive_50env_train.log 2>&1

# %%
# GAIL
# !python train_gail.py \
  --env-id MetaDrive-Tut-1Env-v0 \
  --log-dir MetaDrive-Tut-1Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --expert-dataset-size 30000 \
  > gail_metadrive_1env_train.log 2>&1 
  
# !python train_gail.py \
  --env-id MetaDrive-Tut-5Env-v0 \
  --log-dir MetaDrive-Tut-5Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --expert-dataset-size 30000 \
  > gail_metadrive_5env_train.log 2>&1 

# !python train_gail.py \
  --env-id MetaDrive-Tut-10Env-v0 \
  --log-dir MetaDrive-Tut-10Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --expert-dataset-size 30000 \
  > gail_metadrive_10env_train.log 2>&1 

# !python train_gail.py \
  --env-id MetaDrive-Tut-20Env-v0 \
  --log-dir MetaDrive-Tut-20Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --expert-dataset-size 30000 \
  > gail_metadrive_20env_train.log 2>&1 

# !python train_gail.py \
  --env-id MetaDrive-Tut-50Env-v0 \
  --log-dir MetaDrive-Tut-50Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --expert-dataset-size 30000 \
  > gail_metadrive_50env_train.log 2>&1 

# !python train_gail.py \
  --env-id MetaDrive-Tut-100Env-v0 \
  --log-dir MetaDrive-Tut-100Env-v0 \
  --num-envs 10 \
  --max-steps 1000000 \
  --expert-dataset-size 30000 \
  > gail_metadrive_100env_train.log 2>&1

# %%
# TD3
# !python train_td3.py \
  --env-id MetaDrive-Tut-1Env-v0 \
  --log-dir MetaDrive-Tut-1Env-v0 \
  --max-steps 500000 > td3_metadrive_1env.log 2>&1

# !python train_td3.py \
  --env-id MetaDrive-Tut-5Env-v0 \
  --log-dir MetaDrive-Tut-5Env-v0 \
  --max-steps 500000 > td3_metadrive_5env.log 2>&1

# !python train_td3.py \
  --env-id MetaDrive-Tut-10Env-v0 \
  --log-dir MetaDrive-Tut-10Env-v0 \
  --max-steps 500000 > td3_metadrive_10env.log 2>&1

# !python train_td3.py \
  --env-id MetaDrive-Tut-20Env-v0 \
  --log-dir MetaDrive-Tut-20Env-v0 \
  --max-steps 500000 > td3_metadrive_20env.log 2>&1

# !python train_td3.py \
  --env-id MetaDrive-Tut-50Env-v0 \
  --log-dir MetaDrive-Tut-50Env-v0 \
  --max-steps 500000 > td3_metadrive_50env.log 2>&1

# !python train_td3.py \
  --env-id MetaDrive-Tut-100Env-v0 \
  --log-dir MetaDrive-Tut-100Env-v0 \
  --max-steps 500000 > td3_metadrive_100env.log 2>&1

# %%
# !python train_td3.py \
  --env-id MetaDrive-Tut-100Env-v0 \
  --log-dir MetaDrive-Tut-100Env-v0 \
  --max-steps 500000 > td3_metadrive_100env.log 2>&1

# %%
# Eval PPO
# !python eval_ppo.py \
  --log-dir MetaDrive-Tut-1Env-v0/ppo \
  --num-envs 10 \
  --num-episodes 100 > ppo_metadrive_1env_eval.log 2>&1 

# !python eval_ppo.py \
  --log-dir MetaDrive-Tut-5Env-v0/ppo \
  --num-envs 10 \
  --num-episodes 100 > ppo_metadrive_5env_eval.log 2>&1 

# !python eval_ppo.py \
  --log-dir MetaDrive-Tut-10Env-v0/ppo \
  --num-envs 10 \
  --num-episodes 100 > ppo_metadrive_10env_eval.log 2>&1 

# !python eval_ppo.py \
  --log-dir MetaDrive-Tut-20Env-v0/ppo \
  --num-envs 10 \
  --num-episodes 100 > ppo_metadrive_20env_eval.log 2>&1 

# !python eval_ppo.py \
  --log-dir MetaDrive-Tut-50Env-v0/ppo \
  --num-envs 10 \
  --num-episodes 100 > ppo_metadrive_50env_eval.log 2>&1 

# !python eval_ppo.py \
  --log-dir MetaDrive-Tut-100Env-v0/ppo \
  --num-envs 10 \
  --num-episodes 100 > ppo_metadrive_100env_eval.log 2>&1

# %%
# Eval GAIL
# !python eval_gail.py \
  --log-dir MetaDrive-Tut-1Env-v0/gail \
  --num-envs 10 \
  --num-episodes 100 > gail_metadrive_1env_eval.log 2>&1 

# !python eval_gail.py \
  --log-dir MetaDrive-Tut-5Env-v0/gail \
  --num-envs 10 \
  --num-episodes 100 > gail_metadrive_5env_eval.log 2>&1 

# !python eval_gail.py \
  --log-dir MetaDrive-Tut-10Env-v0/gail \
  --num-envs 10 \
  --num-episodes 100 > gail_metadrive_10env_eval.log 2>&1 

# !python eval_gail.py \
  --log-dir MetaDrive-Tut-20Env-v0/gail \
  --num-envs 10 \
  --num-episodes 100 > gail_metadrive_20env_eval.log 2>&1 

# !python eval_gail.py \
  --log-dir MetaDrive-Tut-50Env-v0/gail \
  --num-envs 10 \
  --num-episodes 100 > gail_metadrive_50env_eval.log 2>&1 

# !python eval_gail.py \
  --log-dir MetaDrive-Tut-100Env-v0/gail \
  --num-envs 10 \
  --num-episodes 100 > gail_metadrive_100env_eval.log 2>&1

# %%
# Eval TD3
# !python eval_td3.py \
  --log-dir MetaDrive-Tut-1Env-v0/td3 \
  --num-envs 10 \
  --num-episodes 100 > td3_metadrive_1env_eval.log 2>&1 

# !python eval_td3.py \
  --log-dir MetaDrive-Tut-5Env-v0/td3 \
  --num-envs 10 \
  --num-episodes 100 > td3_metadrive_5env_eval.log 2>&1

# !python eval_td3.py \
  --log-dir MetaDrive-Tut-10Env-v0/td3 \
  --num-envs 10 \
  --num-episodes 100 > td3_metadrive_10env_eval.log 2>&1 

# !python eval_td3.py \
  --log-dir MetaDrive-Tut-20Env-v0/td3 \
  --num-envs 10 \
  --num-episodes 100 > td3_metadrive_20env_eval.log 2>&1

# !python eval_td3.py \
  --log-dir MetaDrive-Tut-50Env-v0/td3 \
  --num-envs 10 \
  --num-episodes 100 > td3_metadrive_50env_eval.log 2>&1 

# !python eval_td3.py \
  --log-dir MetaDrive-Tut-100Env-v0/td3 \
  --num-envs 10 \
  --num-episodes 100 > td3_metadrive_100env_eval.log 2>&1
